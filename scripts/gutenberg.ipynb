# %%
# https://www.gutenberg.org/ebooks/offline_catalogs.html#the-project-gutenberg-catalog-metadata-in-machine-readable-format
# !wget https://www.gutenberg.org/cache/epub/feeds/pg_catalog.csv

# %%
import pandas as pd

def attach_gutenberg_ids(
    my_catalog_path="../catalog.csv",
    pg_catalog_path="pg_catalog.csv",
    output_path="catalog_with_ids.csv"
):
    # Load your curated catalog and the PG catalog
    my_df = pd.read_csv(my_catalog_path)
    pg_df = pd.read_csv(pg_catalog_path)
    pg_df = pg_df[pg_df["Type"] == "Text"]

    # Normalize titles for matching
    my_df["_title_key"] = my_df["title"].astype(str).str.strip().str.lower()
    pg_df["_title_key"] = pg_df["Title"].astype(str).str.strip().str.lower()

    # Build a mapping from title -> Text# from pg_df
    title_to_id = pg_df.set_index("_title_key")["Text#"].to_dict()

    # Replace the 'id' only, preserve all other columns
    new_ids = []
    not_found = []
    
    for _, row in my_df.iterrows():
        key = row["_title_key"]
        if key in title_to_id:
            new_ids.append(title_to_id[key])
        else:
            new_ids.append(row["id"])  # keep original id if not found
            not_found.append(row["title"])

    # Create a new DataFrame with updated IDs
    my_df["id"] = new_ids
    my_df.drop(columns=["_title_key"], inplace=True)

    # Save to new CSV
    my_df.to_csv(output_path, index=False)
    print(f"Updated catalog saved to '{output_path}'")

    # Report unmatched titles
    if not_found:
        print("\nTitles NOT found in pg_catalog.csv:")
        for title in not_found:
            print(f" - {title}")
    else:
        print("✅ All titles matched successfully.")

attach_gutenberg_ids()
# Out:
# Updated catalog saved to 'catalog_with_ids.csv'
#
# Titles NOT found in pg_catalog.csv:
#  - Tales of the Grotesque and Arabesque

# %%
# !grep "Jane" pg_catalog.csv
# Out:
# 105,Text,1994-02-01,Persuasion,en,"Austen, Jane, 1775-1817",England -- Social life and customs -- 19th century -- Fiction; Psychological fiction; Young women -- Fiction; Motherless families -- Fiction; Rejection (Psychology) -- Fiction; First loves -- Fiction; Dysfunctional families -- Fiction; Ship captains -- Fiction; Love stories; Regency fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: British Literature
# 121,Text,1994-04-01,Northanger Abbey,en,"Austen, Jane, 1775-1817",England -- Social life and customs -- 19th century -- Fiction; Satire; England -- Fiction; Young women -- Fiction; Love stories; Gothic fiction; Horror tales -- Appreciation -- Fiction; Books and reading -- Fiction; Gentry -- England -- Fiction; Marriage -- Economic aspects -- Fiction,PR,Gothic Fiction; Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: Classics of Literature; Category: British Literature
# 141,Text,1994-06-01,Mansfield Park,en,"Austen, Jane, 1775-1817",England -- Fiction; Young women -- Fiction; Love stories; Domestic fiction; Country homes -- Fiction; Adoptees -- Fiction; Children of the rich -- Fiction; Cousins -- Fiction; Uncles -- Fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: British Literature
# 158,Text,1994-08-01,Emma,en,"Austen, Jane, 1775-1817",Humorous stories; England -- Fiction; Young women -- Fiction; Love stories; Fathers and daughters -- Fiction; Bildungsromans; Mate selection -- Fiction; Female friendship -- Fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Humour; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: British Literature
# 161,Text,1994-09-01,Sense and Sensibility,en,"Austen, Jane, 1775-1817",England -- Social life and customs -- 19th century -- Fiction; Inheritance and succession -- Fiction; England -- Fiction; Young women -- Fiction; Love stories; Sisters -- Fiction; Domestic fiction; Mate selection -- Fiction; Social classes -- Fiction; Gentry -- England -- Fiction; Regency fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Novels; Category: Classics of Literature; Category: British Literature
# 490,Text,1996-04-01,Life and Adventures of Calamity Jane,en,"Calamity Jane, 1856-1903","Calamity Jane, 1852-1903; Women -- West (U.S.) -- Biography; Cowgirls -- West (U.S.) -- Biography; Missouri -- History",F590.3,Browsing: Biographies; Browsing: History - American; Browsing: Travel & Geography; Category: Biographies; Category: Adventure; Category: History - American
# 946,Text,1997-06-01,Lady Susan,en,"Austen, Jane, 1775-1817",England -- Fiction; Widows -- Fiction; Mate selection -- Fiction; Mothers and daughters -- Fiction; Epistolary fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: British Literature
# 1212,Text,1998-02-01,Love and Freindship [sic],en,"Austen, Jane, 1775-1817",Essays; Epistolary fiction; England -- Social life and customs -- 18th century -- Fiction,PR,"Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Humour; Category: Novels; Category: Essays, Letters & Speeches; Category: British Literature"
# 1260,Text,1998-03-01,Jane Eyre: An Autobiography,en,"Brontë, Charlotte, 1816-1855; Townsend, F. H. (Frederick Henry), 1868-1920 [Illustrator]",Orphans -- Fiction; England -- Fiction; Young women -- Fiction; Love stories; Governesses -- Fiction; Fathers and daughters -- Fiction; Mentally ill women -- Fiction; Charity-schools -- Fiction; Married people -- Fiction; Country homes -- Fiction; Bildungsromans,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Novels; Category: Classics of Literature; Category: British Literature
# 1325,Text,1998-05-01,Twenty Years at Hull House; with Autobiographical Notes,en,"Addams, Jane, 1860-1935","Women social reformers -- United States -- Biography; Addams, Jane, 1860-1935; Hull House (Chicago, Ill.) -- History; Social service -- Illinois -- Chicago -- History; Social settlements -- Illinois -- Chicago -- History",HV,Browsing: Biographies; Browsing: Culture/Civilization/Society; Browsing: History - American; Category: Biographies; Category: History - American; Category: Sociology
# 1342,Text,1998-06-01,Pride and Prejudice,en,"Austen, Jane, 1775-1817",England -- Fiction; Young women -- Fiction; Love stories; Sisters -- Fiction; Domestic fiction; Courtship -- Fiction; Social classes -- Fiction,PR,Best Books Ever Listings; Harvard Classics; Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Novels; Category: Classics of Literature; Category: British Literature
# 2414,Text,2000-11-01,Cliges: A Romance,en,"Chrétien, de Troyes, active 12th century; Gardiner, Laetitia Jane [Translator]",Arthurian romances; Romances -- Translations into English,PQ,Fantasy; Browsing: Literature; Browsing: Science-Fiction & Fantasy; Browsing: Fiction; Category: Historical Novels; Category: Romance; Category: British Literature
# 2462,Text,2006-03-31,Doña Perfecta,en,"Pérez Galdós, Benito, 1843-1920; Howells, William Dean, 1837-1920 [Author of introduction, etc.]; Serrano, Mary J. (Mary Jane), -1923 [Translator]",Married women -- Fiction; Spain -- Social life and customs -- 19th century -- Fiction; Religion and politics -- Spain -- History -- 19th century -- Fiction; Liberalism -- Spain -- History -- 19th century -- Fiction; Social conflict -- Spain -- History -- 19th century -- Fiction,PQ,Browsing: Culture/Civilization/Society; Browsing: History - General; Browsing: Literature; Browsing: Fiction; Category: Novels
# 3619,Text,2003-01-01,Cousin Maude,en,"Holmes, Mary Jane, 1825-1907",New York (State) -- Fiction; Families -- Fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 4209,Text,2003-07-01,At the Mercy of Tiberius,en,"Evans, Augusta J. (Augusta Jane), 1835-1909","Rome -- History -- Tiberius, 14-37 -- Fiction",PS,Browsing: History - Ancient; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 4246,Text,2003-07-01,Beulah,en,"Evans, Augusta J. (Augusta Jane), 1835-1909",Orphans -- Fiction; Love stories; Women -- Fiction; Southern States -- Fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 4553,Text,2003-10-01,St. Elmo,en,"Evans, Augusta J. (Augusta Jane), 1835-1909","War stories; Domestic fiction; Alabama -- History -- Civil War, 1861-1865 -- Fiction",PS,Browsing: History - American; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 4676,Text,2003-11-01,Outpost,en,"Austin, Jane G. (Jane Goodwin), 1831-1894",Fiction,PS,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 4721,Text,2003-12-01,Darkness and Daylight: A Novel,en,"Holmes, Mary Jane, 1825-1907",Love stories; Guardian and ward -- Fiction; Marriage -- Fiction; Blind -- Fiction; Mental illness -- Fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 4945,Text,2004-01-01,"Jane Allen, Junior",en,"Bancroft, Edith",College students -- Juvenile fiction; Young women -- Juvenile fiction; Women college students -- Juvenile fiction; Basketball stories,PZ,Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels
# 5730,Text,2004-05-01,Friends and Helpers,en,"Eddy, Sarah J. (Sarah Jane), 1851-1945 [Compiler]",Animals -- Fiction; Animal welfare,QL,Browsing: Environmental Issues; Browsing: Nature/Gardening/Animals; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Nature/Gardening/Animals
# 5792,Text,2004-05-01,The Stories Mother Nature Told Her Children,en,"Andrews, Jane, 1833-1887",Natural history -- Juvenile literature,QH,Browsing: Children & Young Adult Reading; Browsing: Nature/Gardening/Animals; Browsing: Science - General; Category: Short Stories; Category: Children & Young Adult Reading; Category: Nature/Gardening/Animals
# 5971,Text,2004-06-01,Jane Cable,en,"McCutcheon, George Barr, 1866-1928",Love stories; Chicago (Ill.) -- Fiction,PS,"Bestsellers, American, 1895-1923; Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Novels; Category: American Literature"
# 5990,Text,2004-06-01,"Rosamond, or, the Youthful Error: A Tale of Riverside; And Other Stories",en,"Holmes, Mary Jane, 1825-1907",Fiction,PS,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 6040,Text,2004-07-01,Stories by English Authors: Ireland,en,"Lover, Samuel, 1797-1868 [Contributor]; Banim, John, 1798-1842 [Contributor]; Barlow, Jane, 1856-1917 [Contributor]; Carleton, William, 1794-1869 [Contributor]; Jessop, George Henry, -1915 [Contributor]","Ireland -- Fiction; English fiction -- 19th century; Short stories, English",PR,Short Stories; Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Short Stories; Category: British Literature
# 6086,Text,2004-07-01,The Scottish Chiefs,en,"Porter, Jane, 1776-1850","Scotland -- History -- War of Independence, 1285-1371 -- Fiction",PR,Historical Fiction; Browsing: History - General; Browsing: History - Warfare; Browsing: Literature; Browsing: Fiction; Category: Historical Novels; Category: Adventure; Category: British Literature
# 6352,Text,2004-08-01,"Dora Deane; Or, The East India Uncle",en,"Holmes, Mary Jane, 1825-1907",Orphans -- Fiction; Domestic fiction; Conduct of life -- Fiction; Uncles -- Fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels
# 6566,Text,2004-09-01,Thaddeus of Warsaw,en,"Porter, Jane, 1776-1850","Poland -- History -- Stanislaus II Augustus, 1764-1795 -- Fiction",PR,Browsing: History - General; Browsing: Literature; Browsing: Fiction; Category: Historical Novels; Category: Novels
# 6860,Text,2004-11-01,Keineth,en,"Abbott, Jane, 1881-1968","Girls -- Juvenile fiction; World War, 1914-1918 -- Juvenile fiction",PZ; PS,Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels; Category: American Literature
# 6954,Text,2004-11-01,Aikenside,en,"Holmes, Mary Jane, 1825-1907",Fiction,PS,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 8404,Text,2005-07-01,Jane Talbot,en,"Brown, Charles Brockden, 1771-1810",Epistolary fiction,PS,"Browsing: Literature; Browsing: Fiction; Category: Novels; Category: Essays, Letters & Speeches; Category: American Literature"
# 8890,Text,2005-09-01,Mary Jane: Her Book,en,"Judson, Clara Ingram, 1879-1960; White, Frances [Illustrator]",Girls -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels
# With the lives of the Duchesses of Gordon and Devonshire",en,"Robinson, Mary, 1758-1800; Thomson, A. T., Mrs., 1797-1862; Wharton, Philip, 1834-1860","Robinson, Mary, 1758-1800; Gordon, Jane Gordon, Duchess of, 1748-1812; Devonshire, Georgiana Spencer Cavendish, Duchess of, 1757-1806",DA,United Kingdom; Browsing: Biographies; Browsing: History - British; Browsing: History - General; Category: Biographies; Category: British Literature
# 10048,Text,2003-11-01,"Billie Bradley and Her Inheritance; Or, The Queer Homestead at Cherry Corners",en,"Wheeler, Janet D.",Girls -- Juvenile fiction; Inheritance and succession -- Juvenile fiction,PZ,Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Adventure; Category: Novels
# 10059,Text,2003-11-01,Aunt Jane's Nieces on Vacation,en,"Baum, L. Frank (Lyman Frank), 1856-1919",Family -- Juvenile fiction; Mystery and detective stories; Uncles -- Juvenile fiction; Cousins -- Juvenile fiction; Farm life -- Juvenile fiction; Young women -- Social life and customs -- Juvenile fiction; Newspaper publishing -- Juvenile fiction; Women authors -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels; Category: American Literature
# 10123,Text,2003-11-01,Aunt Jane's Nieces,en,"Baum, L. Frank (Lyman Frank), 1856-1919",Family -- Juvenile fiction; Young women -- Juvenile fiction; Cousins -- Juvenile fiction; Aunts -- Juvenile fiction; Inheritance and succession -- Juvenile fiction; Families -- Economic aspects -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Novels; Category: American Literature
# 10124,Text,2003-11-01,Aunt Jane's Nieces and Uncle John,en,"Baum, L. Frank (Lyman Frank), 1856-1919",Western stories; Family -- Juvenile fiction; Voyages and travels -- Juvenile fiction; Young women -- Juvenile fiction; Uncles -- Juvenile fiction; Cousins -- Juvenile fiction; West (U.S.) -- Juvenile fiction; California -- Juvenile fiction; Brigands and robbers -- Juvenile fiction; Rocky Mountains -- Description and travel -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Culture/Civilization/Society; Browsing: Travel & Geography; Browsing: Fiction; Category: Humour; Category: Adventure; Category: Novels; Category: American Literature
# 10359,Text,2003-12-01,Aunt Jane's Nieces at Millville,en,"Baum, L. Frank (Lyman Frank), 1856-1919",Mystery and detective stories; Uncles -- Juvenile fiction; Cousins -- Juvenile fiction; Farm life -- Juvenile fiction; Family life -- Juvenile fiction; Young women -- Social life and customs -- Juvenile fiction; Stocks -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Culture/Civilization/Society; Browsing: Fiction; Category: Novels; Category: American Literature
# 10432,Text,2003-12-01,Aunt Jane's Nieces out West,en,"Baum, L. Frank (Lyman Frank), 1856-1919","Family -- Juvenile fiction; Rescues -- Juvenile fiction; Young women -- Juvenile fiction; Cousins -- Juvenile fiction; Motion picture industry -- Juvenile fiction; California, Southern -- Juvenile fiction; Competition -- Juvenile fiction",PZ,Browsing: Children & Young Adult Reading; Browsing: Literature; Browsing: Fiction; Category: Humour; Category: Novels; Category: American Literature
# 10468,Text,2003-12-01,Aunt Jane's Nieces in Society,en,"Baum, L. Frank (Lyman Frank), 1856-1919",Family -- Juvenile fiction; New York (N.Y.) -- Juvenile fiction; Mystery and detective stories; Uncles -- Juvenile fiction; Cousins -- Juvenile fiction; Social classes -- Juvenile fiction; Young women -- Social life and customs -- Juvenile fiction; Debutantes -- Juvenile fiction; Upper class -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Culture/Civilization/Society; Browsing: Fiction; Category: Novels; Category: American Literature
# 10720,Text,2004-01-01,Doctor Pascal,en,"Zola, Émile, 1840-1902; Serrano, Mary J. (Mary Jane), -1923 [Translator]",France -- Social life and customs -- 19th century -- Fiction,PQ,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: French Literature
# For the Use of Teachers, or Mothers Studying with Their Children",en,"Moore, Jane Newell, 1857-1945",Botany -- Juvenile literature,QK,Botany; Children's Instructional Books; Browsing: Children & Young Adult Reading; Browsing: Science - Genetics/Biology/Evolution; Category: Science - Biology; Category: Nature/Gardening/Animals; Category: Teaching & Education
# 11280,Text,2004-02-01,Maggie Miller: The Story of Old Hagar's Secret,en,"Holmes, Mary Jane, 1825-1907",Fiction,PS,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 12052,Text,2004-04-01,Half a Century,en,"Swisshelm, Jane Grey Cannon, 1815-1884","Women's rights -- United States; Antislavery movements -- United States; Swisshelm, Jane Grey Cannon, 1815-1884",E300,Browsing: Biographies; Browsing: Culture/Civilization/Society; Browsing: History - American; Browsing: Politics; Category: Biographies; Category: History - American; Category: History - Modern (1750+); Category: Gender & Sexuality Studies
# 12091,Text,2004-04-01,"The Camp Fire Girls at Long Lake; Or, Bessie King in Summer Camp",en,"Stewart, Jane L.",Camp Fire Girls -- Juvenile fiction; Camping -- Juvenile fiction,PZ,Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Adventure; Category: Novels
# 12099,Text,2004-04-01,"Memories of Jane Cunningham Croly, ""Jenny June""",en,"Woman's Press Club of New York City; Croly, J. C. (Jane Cunningham), 1829-1901 [Contributor]","Croly, J. C. (Jane Cunningham), 1829-1901; Sorosis (New York, N.Y.); Women -- Societies and clubs -- History",PS,Browsing: Biographies; Browsing: Culture/Civilization/Society; Browsing: History - American; Category: Biographies; Category: History - American
# 12104,Text,2004-04-01,Ethelyn's Mistake,en,"Holmes, Mary Jane, 1825-1907",United States -- Social life and customs -- Fiction; Married people -- Fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 12631,Text,2004-06-01,The Seven Little Sisters Who Live on the Round Ball That Floats in the Air,en,"Andrews, Jane, 1833-1887",National characteristics -- Juvenile fiction; Manners and customs -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Culture/Civilization/Society; Category: Children & Young Adult Reading
# An Account of a Journey to the Earthly Canaan and the Land of the Ancient Pharaohs; To Which Are Appended a Brief Consideration of the Geography and History of Palestine, and a Chapter on Churches of Christ in Great Britain",en,"Janes, Don Carlos, 1877-1944",Voyages and travels; Palestine -- Description and travel; Churches of Christ -- Great Britain,DS,Browsing: History - European; Browsing: History - General; Browsing: Travel & Geography; Category: Travel Writing; Category: History - Religious; Category: Religion/Spirituality
# 12765,Text,2004-06-28,Geordie's Tryst: A Tale of Scottish Life,en,"Rae, Janet Milne, 1844-1933",Children -- Conduct of life -- Juvenile fiction; Scotland -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels
# 12835,Text,2004-07-07,'Lena Rivers,en,"Holmes, Mary Jane, 1825-1907",American fiction,PS,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 13110,Text,2004-08-03,Aunt Jane's Nieces at Work,en,"Baum, L. Frank (Lyman Frank), 1856-1919",Family -- Juvenile fiction; Mystery and detective stories; Uncles -- Juvenile fiction; Cousins -- Juvenile fiction; Artists -- Juvenile fiction; New York (State) -- Juvenile fiction; Spies -- Juvenile fiction; Political campaigns -- Juvenile fiction; United States. Congress. House -- Elections -- Juvenile fiction; Young women -- Social life and customs -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Culture/Civilization/Society; Browsing: Crime/Mystery; Browsing: Fiction; Category: Novels; Category: American Literature
# 13177,Text,2004-08-13,Chocolate and Cocoa Recipes and Home Made Candy Recipes,en,"Parloa, Maria, 1843-1909; Hill, Janet McKenzie, 1852-1933",Confectionery; Cooking (Chocolate); Cocoa; Chocolate,TX,Cookbooks and Cooking; Browsing: Cooking & Drinking; Category: Cooking & Drinking; Category: How To ...
# 13577,Text,2004-10-02,"The Meadow-Brook Girls Afloat; Or, the Stormy Cruise of the Red Rover",en,"Aldridge, Janet",Sea stories; Vacations -- Juvenile fiction; Young women -- Juvenile fiction; Boats and boating -- Juvenile fiction,PZ,Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Adventure; Category: Novels
# 13878,Text,2004-10-26,"The English Orphans; Or, A Home in the New World",en,"Holmes, Mary Jane, 1825-1907",Orphans -- Fiction,PS,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# De Aarde en haar Volken, 1885-1887",nl,"Dieulafoy, Jane, 1851-1916",Middle East -- Description and travel; Iran -- Description and travel; Khuzistan (Iran) -- Description and travel,DS,De Aarde en haar Volken; Browsing: History - General; Browsing: Travel & Geography; Category: Travel Writing; Category: Archaeology & Anthropology
# 14089,Text,2004-11-19,Homestead on the Hillside,en,"Holmes, Mary Jane, 1825-1907",Short stories,PS,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 14127,Text,2004-11-22,A Kindergarten Story Book,en,"Hoxie, Jane L. (Jane Lincoln), 1863-1930",Children's stories,PZ,Browsing: Children & Young Adult Reading; Browsing: Language & Communication; Browsing: Literature; Category: Short Stories; Category: Children & Young Adult Reading
# De Aarde en haar Volken, 1906",nl,"Dieulafoy, Jane, 1851-1916",Spain -- Description and travel,DP,De Aarde en haar Volken; Browsing: Culture/Civilization/Society; Browsing: History - General; Browsing: Travel & Geography; Category: Travel Writing; Category: History - Other
# 14889,Text,2005-02-03,"The Meadow-Brook Girls Under Canvas; Or, Fun and Frolic in the Summer Camp",en,"Aldridge, Janet",Friendship -- Juvenile fiction; Camping -- Juvenile fiction; Hazing -- Juvenile fiction,PZ,Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Adventure; Category: Novels
# 15192,Text,2005-02-27,Salomy Jane,en,"Harte, Bret, 1836-1902; Fisher, Harrison, 1875-1934 [Illustrator]; Keller, Arthur Ignatius, 1866-1924 [Illustrator]",Man-woman relationships -- Fiction; Robbers and outlaws -- Fiction,PS,"Movie Books; Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Crime, Thrillers and Mystery; Category: Novels; Category: American Literature"
# 15221,Text,2005-03-01,A New Conscience and an Ancient Evil,en,"Addams, Jane, 1860-1935",Prostitution; Prostitution -- Illinois -- Chicago,HQ,"Bestsellers, American, 1895-1923; Browsing: Culture/Civilization/Society; Browsing: Politics; Browsing: Sociology; Category: Gender & Sexuality Studies; Category: Sociology; Category: Politics"
# 15275,Text,2005-03-07,Bessie's Fortune: A Novel,en,"Holmes, Mary Jane, 1825-1907",Fiction,PS,Browsing: Literature; Browsing: Fiction; Category: Historical Novels; Category: Novels
# 15321,Text,2005-03-10,Tracy Park: A Novel,en,"Holmes, Mary Jane, 1825-1907",Fiction,PS,Browsing: Literature; Browsing: Fiction; Category: Novels
# 15470,Text,2005-03-26,Inez: A Tale of the Alamo,en,"Evans, Augusta J. (Augusta Jane), 1835-1909","Historical fiction; Sieges -- Fiction; Alamo (San Antonio, Tex.) -- Siege, 1836 -- Fiction",PS,Browsing: History - American; Browsing: Fiction; Category: Historical Novels; Category: American Literature
# 15487,Text,2005-03-28,Democracy and Social Ethics,en,"Addams, Jane, 1860-1935",Social sciences; United States -- Social conditions -- 1865-1918; Social ethics,HN,"Browsing: Culture/Civilization/Society; Browsing: Politics; Category: Essays, Letters & Speeches; Category: Philosophy & Ethics; Category: Sociology"
# 15607,Text,2005-04-12,"Family Pride; Or, Purified by Suffering",en,"Holmes, Mary Jane, 1825-1907",Dime novels; American fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 15726,Text,2005-04-28,"The Camp Fire Girls on the Farm; Or, Bessie King's New Chum",en,"Stewart, Jane L.",Camp Fire Girls -- Juvenile fiction,PZ,Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Adventure; Category: Novels
# 15892,Text,2005-05-24,The Education of Catholic Girls,en,"Stuart, Janet Erskine, 1857-1914",Women -- Education; Catholic Church -- Education,LC,Browsing: Gender & Sexuality Studies; Browsing: Religion/Spirituality/Paranormal; Browsing: Teaching & Education; Category: Religion/Spirituality; Category: Parenthood & Family Relations; Category: Teaching & Education
# 15954,Text,2005-05-31,Mary Jane—Her Visit,en,"Judson, Clara Ingram, 1879-1960; White, Frances [Illustrator]",Girls -- Juvenile fiction; Country life -- Juvenile fiction; Grandparents -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels
# 16005,Text,2005-06-07,"Jane Sinclair; Or, The Fawn Of Springvale
# 16138,Text,2005-06-27,The Cromptons,en,"Holmes, Mary Jane, 1825-1907",Fiction,PS,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 16150,Text,2005-06-29,Miss McDonald,en,"Holmes, Mary Jane, 1825-1907",Man-woman relationships -- Fiction; Divorce -- Fiction; Marriage -- Fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: British Literature
# 16221,Text,2005-07-06,The Spirit of Youth and the City Streets,en,"Addams, Jane, 1860-1935",Child rearing; Urban youth,HQ,Browsing: Culture/Civilization/Society; Browsing: Parenthood & Family Relations; Browsing: Sociology; Category: Sociology; Category: Parenthood & Family Relations
# 16235,Text,2005-07-07,Jane Eyre; ou Les mémoires d'une institutrice,fr,"Brontë, Charlotte, 1816-1855; Souvestre, Lesbazeilles [Translator]",Orphans -- Fiction; England -- Fiction; Young women -- Fiction; Love stories; Governesses -- Fiction; Fathers and daughters -- Fiction; Mentally ill women -- Fiction; Charity-schools -- Fiction; Married people -- Fiction; Country homes -- Fiction; Bildungsromans,PR,FR Littérature; Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: British Literature
# 16566,Text,2005-08-21,Aunt Jane's Nieces Abroad,en,"Baum, L. Frank (Lyman Frank), 1856-1919",Family -- Juvenile fiction; Voyages and travels -- Juvenile fiction; Young women -- Juvenile fiction; Cousins -- Juvenile fiction; Italy -- Juvenile fiction; Brigands and robbers -- Juvenile fiction; Americans -- Italy -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Travel & Geography; Browsing: Fiction; Category: Adventure; Category: Novels; Category: Travel Writing; Category: American Literature
# 16567,Text,2005-08-21,Aunt Jane's Nieces in the Red Cross,en,"Baum, L. Frank (Lyman Frank), 1856-1919; Hall, N. P. [Illustrator]","War stories; Family -- Juvenile fiction; Red Cross and Red Crescent -- Juvenile fiction; Nurses -- Juvenile fiction; World War, 1914-1918 -- Medical care -- Juvenile fiction",PZ,Browsing: Children & Young Adult Reading; Browsing: History - Warfare; Browsing: Fiction; Category: Adventure; Category: Novels; Category: American Literature
# 16662,Text,2005-09-05,Bad Hugh,en,"Holmes, Mary Jane, 1825-1907",Fiction,PS,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 17087,Text,2005-11-18,Ancient Art and Ritual,en,"Harrison, Jane Ellen, 1850-1928","Art, Primitive; Aesthetics; Ritual",BH,"Anthropology; Browsing: Art & Photography; Browsing: Philosophy & Ethics; Browsing: Religion/Spirituality/Paranormal; Browsing: Sociology; Category: Mythology, Legends & Folklore; Category: History - Ancient; Category: Art; Category: Philosophy & Ethics"
# 17099,Text,2005-11-18,"The Meadow-Brook Girls by the Sea; Or, The Loss of The Lonesome Bar",en,"Aldridge, Janet",Sea stories; Mystery and detective stories; Cuba -- Juvenile fiction; Smuggling -- Juvenile fiction,PZ,Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Crime/Mystery; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Adventure; Category: Novels
# 17260,Text,2005-12-12,Tempest and Sunshine,en,"Holmes, Mary Jane, 1825-1907",United States -- Social life and customs -- 19th century -- Fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Novels; Category: American Literature
# 17718,Text,2006-02-08,Infelice,en,"Evans, Augusta J. (Augusta Jane), 1835-1909",United States -- Social life and customs -- 19th century -- Fiction; Women -- Social conditions -- Fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 17790,Text,2006-02-18,Jane Field: A Novel,en,"Freeman, Mary Eleanor Wilkins, 1852-1930",New England -- Fiction,PS,Browsing: Fiction; Category: Novels; Category: American Literature
# 17797,Text,2006-02-19,Memoir of Jane Austen,en,"Austen-Leigh, James Edward, 1798-1874","Novelists, English -- 19th century -- Biography; Austen, Jane, 1775-1817",PR,Browsing: Biographies; Browsing: Literature; Category: Biographies
# 17816,Text,2006-02-21,Letters from Egypt,en,"Duff Gordon, Lucie, Lady, 1821-1869; Meredith, George, 1828-1909 [Commentator]; Ross, Janet, 1842-1927 [Editor]","Egypt -- Description and travel; Duff Gordon, Lucie, Lady, 1821-1869 -- Correspondence",DT,"Browsing: Biographies; Browsing: History - General; Browsing: Travel & Geography; Category: Essays, Letters & Speeches; Category: Travel Writing"
# 17865,Text,2006-02-26,"The Meadow-Brook Girls in the Hills; Or, The Missing Pilot of the White Mountains",en,"Aldridge, Janet",Hiking -- Juvenile fiction; Young women -- Juvenile fiction; White Mountains (N.H. and Me.) -- Juvenile fiction,PZ,Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Adventure; Category: Novels
# 17962,Text,2006-03-10,Luar de Janeiro,pt,"Gil, Augusto, 1873-1929",Poetry,PQ,PT Poesia; Browsing: Literature; Browsing: Poetry; Category: Poetry
# 18681,Text,2006-06-25,Across the Fruited Plain,en,"Means, Florence Crannell, 1891-1980; Smalley, Janet, 1893- [Illustrator]",Migrant agricultural laborers -- United States -- Juvenile fiction; Poor families -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Culture/Civilization/Society; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels; Category: American Literature
# The Ascomycetes of Ohio IV and V",en,"Fink, Bruce, 1861-1927; Hilker, Leafy Jane Corrington, 1889-",Ascomycetes,QH; QK,Biology; Browsing: Science - General; Browsing: Science - Genetics/Biology/Evolution; Category: Science - Biology; Category: Nature/Gardening/Animals
# 18957,Text,2006-07-31,Strangers at Lisconnel,en,"Barlow, Jane, 1856-1917",Ireland -- Social life and customs -- Fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels
# 19015,Text,2006-08-09,"Jane Allen, Right Guard",en,"Bancroft, Edith",College students -- Juvenile fiction; Young women -- Juvenile fiction; Women college students -- Juvenile fiction; Basketball stories,PZ,Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels; Category: American Literature
# 19057,Text,2006-08-16,Red-Robin,en,"Abbott, Jane, 1881-1968; Richards, Harriet Roosevelt, -1932 [Illustrator]",Friendship -- Juvenile fiction; Family -- Juvenile fiction; Inheritance and succession -- Juvenile fiction; Poor children -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Novels; Category: American Literature
# With Fifty Illustrations of Original Dishes",en,"Hill, Janet McKenzie, 1852-1933",Salads; Sandwiches; Chafing dish cooking,TX,Cookbooks and Cooking; Browsing: Cooking & Drinking; Category: Cooking & Drinking; Category: How To ...
# From Henry VII. to Mary",en,"Hume, David, 1711-1776","Great Britain -- History -- Henry VIII, 1509-1547; Great Britain -- History -- Mary I, 1553-1558; Great Britain -- History -- Henry VII, 1485-1509; Great Britain -- History -- Edward VI, 1547-1553; Grey, Jane, Lady, 1537-1554",DA,United Kingdom; Browsing: History - British; Browsing: History - General; Category: History - British; Category: History - Modern (1750+); Category: History - Royalty
# De Aarde en haar Volken, 1907",nl,"Dieulafoy, Jane, 1851-1916",Spain -- Description and travel,DP,De Aarde en haar Volken; Browsing: History - European; Browsing: Travel & Geography; Category: Travel Writing; Category: History - European; Category: Archaeology & Anthropology
# 19458,Text,2006-10-04,The loyalists,en,"West, Jane, 1758-1852","Great Britain -- History -- Civil War, 1642-1649 -- Fiction",PR,Browsing: History - British; Browsing: Literature; Browsing: Fiction; Category: Historical Novels; Category: Novels; Category: British Literature
# 19702,Text,2006-11-02,The Rector of St. Mark's,en,"Holmes, Mary Jane, 1825-1907",Clergy -- Fiction,PS,Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Novels; Category: American Literature
# 19839,Sound,2006-11-18,Emma,en,"Austen, Jane, 1775-1817",Humorous stories; England -- Fiction; Young women -- Fiction; Love stories; Fathers and daughters -- Fiction; Bildungsromans; Mate selection -- Fiction; Female friendship -- Fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Humour; Browsing: Literature; Browsing: Fiction
# 20018,Text,2006-12-04,"Evenings at Donaldson Manor; Or, The Christmas Guest",en,"McIntosh, Maria J. (Maria Jane), 1803-1878",Fiction; Christmas stories,PS,Christmas; Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 20230,Text,2006-12-30,Jane Journeys On,en,"Mitchell, Ruth Comfort, 1882-1954",New York (N.Y.) -- Fiction; Young women -- Fiction; Mate selection -- Fiction; Courtship -- Fiction; Women authors -- Fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 20682,Sound,2007-02-03,Northanger Abbey,en,"Austen, Jane, 1775-1817",England -- Social life and customs -- 19th century -- Fiction; Satire; England -- Fiction; Young women -- Fiction; Love stories; Gothic fiction; Horror tales -- Appreciation -- Fiction; Books and reading -- Fiction; Gentry -- England -- Fiction; Marriage -- Economic aspects -- Fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction
# 20686,Sound,2007-02-03,Pride and Prejudice,en,"Austen, Jane, 1775-1817",England -- Fiction; Young women -- Fiction; Love stories; Sisters -- Fiction; Domestic fiction; Courtship -- Fiction; Social classes -- Fiction,PR,Best Books Ever Listings; Harvard Classics; Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction
# 20687,Sound,2007-02-03,Pride and Prejudice,en,"Austen, Jane, 1775-1817",England -- Fiction; Young women -- Fiction; Love stories; Sisters -- Fiction; Domestic fiction; Courtship -- Fiction; Social classes -- Fiction,PR,Best Books Ever Listings; Harvard Classics; Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction
# The Camp Fire Girls In the Woods",en,"Stewart, Jane L.",Camp Fire Girls -- Juvenile fiction,PZ,Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels; Category: American Literature
# 20747,Text,2007-03-05,Deaconesses in Europe and their Lessons for America,en,"Bancroft, Jane M. (Jane Marie), 1847-1932",Deaconesses,BV; HQ,Christianity; Browsing: History - General; Browsing: Philosophy & Ethics; Browsing: Religion/Spirituality/Paranormal; Category: History - European; Category: History - Modern (1750+); Category: History - Religious; Category: Gender & Sexuality Studies; Category: Religion/Spirituality
# 20822,Text,2007-03-15,"The Camp Fire Girls on the March; Or, Bessie King's Test of Friendship",en,"Stewart, Jane L.",Camp Fire Girls -- Juvenile fiction,PZ,Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Adventure; Category: Novels
# 21839,Text,2007-06-15,Sense and Sensibility,en,"Austen, Jane, 1775-1817; Dobson, Austin, 1840-1921 [Commentator]; Thomson, Hugh, 1860-1920 [Illustrator]",England -- Social life and customs -- 19th century -- Fiction; Inheritance and succession -- Fiction; England -- Fiction; Young women -- Fiction; Love stories; Sisters -- Fiction; Domestic fiction; Mate selection -- Fiction; Social classes -- Fiction; Gentry -- England -- Fiction; Regency fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Novels; Category: Classics of Literature; Category: British Literature
# 21993,Text,2007-07-04,The Devil's Pool,en,"Sand, George, 1804-1876; Abot, Eugène-Michel-Joseph, 1836-1894 [Illustrator]; Sedgwick, Ellery, 1872-1960 [Translator]; Sedgwick, Jane Minot [Translator]","Pastoral fiction, French",PQ,Harvard Classics; Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: French Literature
# 22052,Text,2007-07-12,Standish of Standish: A Story of the Pilgrims,en,"Austin, Jane G. (Jane Goodwin), 1831-1894","Massachusetts -- History -- New Plymouth, 1620-1691 -- Fiction",PS,Browsing: History - American; Browsing: Literature; Browsing: Fiction; Category: Historical Novels; Category: Romance; Category: Novels; Category: American Literature
# 22536,Text,2007-09-07,"Jane Austen, Her Life and Letters: A Family Record",en,"Austen-Leigh, William, 1843-1921; Austen-Leigh, Richard Arthur, 1872-1961","Novelists, English -- 19th century -- Family relationships; Austen, Jane, 1775-1817; Austen, Jane, 1775-1817 -- Family",PR,Browsing: Biographies; Browsing: Culture/Civilization/Society; Browsing: Literature; Category: Biographies; Category: British Literature
# 22652,Text,2007-09-17,A Campfire Girl's Test of Friendship,en,"Stewart, Jane L.",Camp Fire Girls -- Juvenile fiction,PZ,Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels
# 22953,Sound,2007-10-01,Lady Susan,en,"Austen, Jane, 1775-1817",England -- Fiction; Widows -- Fiction; Mate selection -- Fiction; Mothers and daughters -- Fiction; Epistolary fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction
# 22954,Sound,2007-10-01,Love and Freindship [sic],en,"Austen, Jane, 1775-1817",Epistolary fiction; England -- Social life and customs -- 18th century -- Fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction
# 22962,Sound,2007-10-01,Mansfield Park,en,"Austen, Jane, 1775-1817",England -- Fiction; Young women -- Fiction; Love stories; Domestic fiction; Country homes -- Fiction; Adoptees -- Fiction; Children of the rich -- Fiction; Cousins -- Fiction; Uncles -- Fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction
# 22963,Sound,2007-10-01,Persuasion,en,"Austen, Jane, 1775-1817",England -- Social life and customs -- 19th century -- Fiction; Psychological fiction; Young women -- Fiction; Motherless families -- Fiction; Rejection (Psychology) -- Fiction; First loves -- Fiction; Dysfunctional families -- Fiction; Ship captains -- Fiction; Love stories; Regency fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction
# 22964,Sound,2007-10-01,Sense and Sensibility,en,"Austen, Jane, 1775-1817",England -- Social life and customs -- 19th century -- Fiction; Inheritance and succession -- Fiction; England -- Fiction; Young women -- Fiction; Love stories; Sisters -- Fiction; Domestic fiction; Mate selection -- Fiction; Social classes -- Fiction; Gentry -- England -- Fiction; Regency fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction
# 22998,Text,2007-10-17,Janet of the Dunes,en,"Comstock, Harriet T. (Harriet Theresa), 1860-1943",Young women -- Fiction; Ship captains -- Fiction,PS,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 23069,Text,2007-10-17,"Janet McLaren, the Faithful Nurse",en,"Kingston, William Henry Giles, 1814-1880",Orphans -- Juvenile fiction; Siblings -- Juvenile fiction; Canada -- Juvenile fiction; Scotland -- Juvenile fiction; Guardian and ward -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Novels; Category: British Literature
# 23077,Sound,2007-10-01,Jane Eyre,en,"Brontë, Charlotte, 1816-1855",Orphans -- Fiction; England -- Fiction; Young women -- Fiction; Love stories; Governesses -- Fiction; Fathers and daughters -- Fiction; Mentally ill women -- Fiction; Charity-schools -- Fiction; Married people -- Fiction; Country homes -- Fiction; Bildungsromans,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction
# 23266,Text,2007-10-31,Janet's Love and Service,en,"Robertson, Margaret M. (Margaret Murray), 1821-1897",Family -- Fiction; Christian life -- Fiction; Motherless families -- Fiction; Canada -- Fiction; New England -- Fiction; Clergy -- Family relationships -- Fiction; Scotland -- Emigration and immigration -- Fiction; Household employees -- Fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Fiction; Category: Historical Novels; Category: Novels
# 23368,Text,2007-11-06,The courting of Lady Jane,en,"Bacon, Josephine Daskam, 1876-1961","Middle-aged persons -- Fiction; Love stories, American",PS,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Novels; Category: American Literature
# 23455,Text,2007-11-12,Plain Jane,en,"George, G. M.; Fry, G. M. C. [Illustrator]",Children's poetry; Talebearing -- Juvenile poetry,PZ,Browsing: Children & Young Adult Reading; Browsing: Poetry; Category: Children & Young Adult Reading; Category: Novels
# 23894,Text,2007-12-18,"Billie Bradley at Three Towers Hall; Or, Leading a Needed Rebellion",en,"Wheeler, Janet D.",Boarding schools -- Juvenile fiction; Girls -- Juvenile fiction,PZ,Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Adventure; Category: Novels
# 23955,Text,2007-12-21,Chicken Little Jane,en,"Ritchie, Lily Munsell",Family -- Juvenile fiction; Silver -- Juvenile fiction; Caves -- Juvenile fiction; Weddings -- Juvenile fiction; Holidays -- Juvenile fiction; Birthdays -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels; Category: American Literature
# 24167,Text,2008-01-04,Careless Jane and Other Tales,en,"Pyle, Katharine, 1863-1938","Children's poetry, American; Conduct of life -- Juvenile poetry",PZ,Browsing: Children & Young Adult Reading; Browsing: Poetry; Category: Short Stories; Category: Children & Young Adult Reading
# De Aarde en haar Volken, 1909",nl,"Dieulafoy, Jane, 1851-1916",Spain -- Description and travel; Castile (Spain); Andalusia (Spain),DP,Browsing: History - General; Browsing: Travel & Geography; Category: Travel Writing
# 24519,Text,2008-02-04,The Story of Rouen,en,"Cook, Theodore Andrea, 1867-1928; Cook, Jane E. (Jane Elizabeth), 1836-1920 [Illustrator]; James, Helen M. (Helen Mary), 1863-1900 [Illustrator]",Rouen (France) -- History; Rouen (France) -- Description and travel,DC,France; Mediæval Town Series; Browsing: History - European; Browsing: Travel & Geography; Category: Travel Writing; Category: History - European; Category: Architecture
# 24699,Text,2008-02-26,Some Personal Recollections of Dr. Janeway,en,"Clark, James Bayard, 1869-1947","Physicians -- United States -- Biography; Janeway, Edward Gamaliel, 1841-1911",CT; R,Browsing: Biographies; Browsing: History - General; Category: Biographies; Category: Health & Medicine
# With Special Reference to the Effects of Alcoholic Drinks, Stimulants, and Narcotics upon The Human System",en,"Andrews, Jane, 1833-1887",Physiology -- Juvenile literature; Hygiene -- Juvenile literature,QP,Physiology; Browsing: Children & Young Adult Reading; Browsing: Health & Medicine; Category: Children & Young Adult Reading; Category: Health & Medicine; Category: Drugs/Alcohol/Pharmacology; Category: Teaching & Education
# 25762,Text,2008-06-12,"Billie Bradley on Lighthouse Island; Or, The Mystery of the Wreck",en,"Wheeler, Janet D.",Detective and mystery stories; Islands -- Juvenile fiction; Shipwrecks -- Juvenile fiction; Students -- Juvenile fiction; Missing children -- Juvenile fiction,PZ,"Children's Book Series; Browsing: Children & Young Adult Reading; Browsing: Crime/Mystery; Category: Children & Young Adult Reading; Category: Crime, Thrillers and Mystery; Category: Adventure; Category: Novels"
# 25946,Text,2008-07-01,Gevoel en verstand,nl,"Austen, Jane, 1775-1817; Loman-van Uildriks, Gonne, 1863-1921 [Translator]",England -- Social life and customs -- 19th century -- Fiction; Inheritance and succession -- Fiction; England -- Fiction; Young women -- Fiction; Love stories; Sisters -- Fiction; Domestic fiction; Mate selection -- Fiction; Social classes -- Fiction,PR,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Novels; Category: Classics of Literature; Category: British Literature
# A Monthly Magazine of Household Interest",en,"Various; McClure, Mary Jane [Editor]",Cooking -- Periodicals; Menus -- Periodicals,TX,Cookbooks and Cooking; Armour's Monthly Cook Book; Browsing: Cooking & Drinking; Browsing: Encyclopedias/Dictionaries/Reference; Category: Cooking & Drinking; Category: How To ...
# November, 1921",en,"Various; Hill, Janet McKenzie, 1852-1933 [Editor]",Cooking -- Periodicals; Home economics -- Periodicals,TX,Cookbooks and Cooking; Browsing: Cooking & Drinking; Browsing: Encyclopedias/Dictionaries/Reference; Category: American Literature; Category: Cooking & Drinking; Category: How To ...
# 26044,Text,2008-07-12,"Peter and Jane; Or, The Missing Heir",en,"Macnaughtan, S. (Sarah), 1864-1916",Inheritance and succession -- Fiction,PR,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: British Literature
# 26145,Text,2008-07-29,The Tell El Amarna Period,en,"Niebuhr, Carl, 1861-1927; Hutchison, J. (Jane) [Translator]","Middle East -- History; Tell el-Amarna (Egypt); Egypt -- History, Ancient; Palestine -- History",DS,Browsing: Culture/Civilization/Society; Browsing: History - Ancient; Browsing: History - General; Category: History - Ancient
# 26301,Sound,2008-08-01,Pride and Prejudice,en,"Austen, Jane, 1775-1817",England -- Fiction; Young women -- Fiction; Love stories; Sisters -- Fiction; Domestic fiction; Courtship -- Fiction; Social classes -- Fiction,PR,Best Books Ever Listings; Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction
# 26344,Text,2008-08-18,Letters of a Dakota Divorcee,en,"Burr, Jane, 1882?-1958",Divorced women -- Fiction,PS,Browsing: Gender & Sexuality Studies; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 26517,Text,2008-09-03,Mary Jane's City Home,en,"Judson, Clara Ingram, 1879-1960; Gooch, Thelma, 1895-1973 [Illustrator]",Girls -- Juvenile fiction; Family life -- Juvenile fiction; Chicago (Ill.) -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels; Category: American Literature
# ...
# 70821,Text,2023-05-20,A Suse,fr,"Dieulafoy, Jane, 1851-1916",Iran -- Description and travel; Susa (Extinct city) -- Antiquities; Archaeology -- Iran,DS,Browsing: Archaeology; Browsing: History - General; Browsing: Travel & Geography; Category: Biographies; Category: Travel Writing; Category: Archaeology & Anthropology
# 70870,Text,2023-05-27,Marian Grey,en,"Holmes, Mary Jane, 1825-1907",New York (N.Y.) -- Fiction; Inheritance and succession -- Fiction; Man-woman relationships -- Fiction; Kentucky -- Fiction; Runaway wives -- Fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Novels; Category: American Literature
# 70883,Text,2023-05-30,Doctor Hathern's daughters,en,"Holmes, Mary Jane, 1825-1907",Sisters -- Fiction; Domestic fiction; Mate selection -- Fiction; Man-woman relationships -- Fiction; Virginia -- Fiction; Americans -- Europe -- Fiction; Twins -- Fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Literature; Browsing: Fiction; Category: Historical Novels; Category: Novels; Category: American Literature
# 70893,Text,2023-06-02,"The abandoned farm, and Connie's mistake",en,"Holmes, Mary Jane, 1825-1907; Grant, Gordon, 1875-1962 [Illustrator]",American fiction -- 20th century,PS,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 70966,Text,2023-06-12,The Tracy diamonds,en,"Holmes, Mary Jane, 1825-1907",American fiction -- 19th century,PS,Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Humour; Category: Novels; Category: American Literature
# 70986,Text,2023-06-16,Mildred,en,"Holmes, Mary Jane, 1825-1907",American fiction -- 19th century; Adopted children -- Fiction; Dime novels,PS,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 71099,Text,2023-07-03,Maggie Lee!,en,"Holmes, Mary Jane, 1825-1907","Short stories, American; American fiction -- 19th century",PS,Browsing: History - American; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 71108,Text,2023-07-03,Meadow Brook,en,"Holmes, Mary Jane, 1825-1907",American fiction -- 19th century,PS,Browsing: History - American; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 71464,Text,2023-08-21,Florentine palaces & their stories,en,"Ross, Janet, 1842-1927; Marchi, Adelaide [Illustrator]",Florence (Italy) -- History,DG,Browsing: Culture/Civilization/Society; Browsing: History - European; Browsing: History - General; Category: History - European; Category: Architecture
# 71709,Text,2023-09-23,Lady Jane,en,"Jamison, C. V. (Cecilia Viets), 1837?-1909; Birch, Reginald B. (Reginald Bathurst), 1856-1943 [Illustrator]",Orphans -- Juvenile fiction; Friendship -- Juvenile fiction; Kindness -- Juvenile fiction; Girls -- Juvenile fiction; Children and death -- Juvenile fiction; Inheritance and succession -- Juvenile fiction; Pets -- Juvenile fiction; Parent and child -- Juvenile fiction; Theft -- Juvenile fiction; Louisiana -- Juvenile fiction; New Orleans (La.) -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Novels; Category: American Literature
# 71781,Text,2023-10-02,"The poetical works of Janet Little, the Scotch milkmaid",en,"Little, Janet, 1759-1813",Scottish poetry -- 18th century; English poetry -- Scottish authors -- 18th century,PR,Browsing: Literature; Browsing: Poetry; Category: Poetry; Category: British Literature
# 71825,Text,2023-10-07,All that happened in a week,en,"Findlater, Jane Helen, 1866-1946; Petherick, Rosa C., 1871-1931 [Illustrator]",Vacations -- Juvenile fiction; Girls -- Juvenile fiction; Aunts -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels
# 72020,Text,2023-11-04,Janet's boys,en,"Lyster, Annette; Stacey, W. S. (Walter S.), 1846-1929 [Illustrator]",Didactic fiction; Domestic fiction; Christian fiction; England -- Juvenile fiction; Mothers and sons -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Literature; Browsing: Fiction; Category: Novels; Category: British Literature
# 72038,Text,2023-11-05,Captain Mary Miller,en,"Robinson, Harriet Jane Hanson, 1825-1911",Paddle steamers -- Mississippi River -- Drama; Ship captains -- Drama; Ship captains' spouses -- Drama,PS,Browsing: Literature; Browsing: Fiction; Category: Plays/Films/Dramas; Category: British Literature; Category: Gender & Sexuality Studies
# 72271,Text,2023-11-30,The Russian novelists,en,"Vogüé, Eugène-Melchior, vicomte de, 1848-1910; Edmands, Jane Loring, 1839-1913 [Translator]","Tolstoy, Leo, graf, 1828-1910; Russian fiction -- History and criticism; Dostoyevsky, Fyodor, 1821-1881; Turgenev, Ivan Sergeevich, 1818-1883; Gogol, Nikolai Vasilevich, 1809-1852; Pushkin, Aleksandr Sergeevich, 1799-1837",PG,"Browsing: Literature; Browsing: Russian Interest; Category: Essays, Letters & Speeches; Category: Russian Literature"
# 72296,Text,2023-12-02,"Trial of Jane Leigh Perrot, at Taunton Assizes, on Saturday the 29th day of March, 1800; charged with stealing a card of lace, in the shop of Elizabeth Gregory, haberdasher & milliner, of the city of Bath",en,"Leigh Perrot, Jane Cholmeley, 1746-1836","Leigh Perrot, Jane Cholmeley, 1746-1836 -- Trials, litigation, etc.; Trials (Larceny) -- England -- Taunton",KD,Browsing: History - British; Browsing: Law & Criminology; Category: History - Other; Category: History - British; Category: History - Modern (1750+); Category: Law & Criminology
# 72757,Text,2024-01-19,Loom and spindle,en,"Robinson, Harriet Jane Hanson, 1825-1911; Wright, Carroll D. (Carroll Davidson), 1840-1909 [Author of introduction, etc.]; Larcom, Lucy, 1824-1893 [Contributor]",Women textile workers -- Massachusetts -- Lowell -- Biography; Factory system; Lowell offering; Lowell (Mass.) -- Social conditions,HD,Browsing: Biographies; Browsing: Culture/Civilization/Society; Browsing: History - American; Category: Biographies; Category: History - American; Category: History - Modern (1750+); Category: History - Schools & Universities
# 73483,Text,2024-04-27,Plane Jane,en,"Davis, Frederick C. (Frederick Clyde), 1902-1977",Short stories; Air pilots -- Fiction; Women air pilots -- Fiction; Airplane racing -- Fiction,PS,Browsing: Literature; Browsing: Fiction; Category: Romance; Category: Adventure; Category: Novels; Category: American Literature
# 73685,Text,2024-05-24,The case against spiritualism,en,"Stoddart, Jane T., 1863-1944",Spiritualism,BF,Browsing: Philosophy & Ethics; Browsing: Psychiatry/Psychology; Browsing: Religion/Spirituality/Paranormal; Category: Religion/Spirituality
# 73789,Text,2024-06-07,Primitive Athens as described by Thucydides,en,"Harrison, Jane Ellen, 1850-1928",Athens (Greece) -- Description and travel; Athens (Greece) -- Antiquities,DF,Browsing: History - European; Browsing: Travel & Geography; Category: History - Ancient; Category: Archaeology & Anthropology
# 74012,Text,2024-07-11,Janet's college career,en,"Blanchard, Amy Ella, 1856-1926",College students -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels
# 74201,Text,2024-08-07,Instructions in gardening for ladies,en,"Loudon, Mrs. (Jane), 1807-1858; Corbould, H. (Henry), 1787-1844 [Illustrator]; Williams, S. [Illustrator]",Gardening -- Great Britain,SB,Browsing: How To...; Browsing: Nature/Gardening/Animals; Category: How To ...; Category: Nature/Gardening/Animals
# 74233,Text,2024-08-12,"Fragment of a novel written by Jane Austen, January-March 1817",en,"Austen, Jane, 1775-1817; Chapman, R. W. (Robert William), 1881-1960 [Editor]","England -- Social life and customs -- 19th century -- Fiction; Young women -- Fiction; Sussex (England) -- Fiction; Unfinished books; Heywood, Charlotte (Fictitious character) -- Fiction",PR,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: British Literature
# 74414,Text,2024-09-14,Medaglioni,it,"Nencioni, Enrico, 1837-1896","Du Barry, Jeanne Bécu, comtesse, 1743-1793; Pompadour, Jeanne Antoinette Poisson, marquise de, 1721-1764; Women -- Biography; Arnould, Madeleine Sophie, 1744-1803; Browning, Elizabeth Barrett, 1806-1861; Carlyle, Jane Welsh, 1801-1866; Guiccioli, Teresa, contessa di, 1800-1873; Lespinasse, Julie de, 1732-1776; Krüdener, Barbara Juliane, Freifrau von, 1764-1824; Rachel, 1821?-1858; Rousseau, Jean-Jacques, 1712-1778 -- Relations with women",CT; PQ,Browsing: Biographies; Browsing: Literature; Category: Biographies; Category: History - European; Category: Gender & Sexuality Studies
# 74442,Text,2024-09-19,Dragon's teeth,en,"Queirós, Eça de, 1845-1900; Serrano, Mary J. (Mary Jane), -1923 [Translator]",Adultery -- Fiction; Extortion -- Fiction; Spouses -- Fiction; Lisbon (Portugal) -- Fiction; Portuguese fiction -- Translations into English,PQ,Browsing: Culture/Civilization/Society; Browsing: Fiction; Category: Novels
# 74624,Text,2024-10-22,The Imperial Japanese Navy,en,"Jane, Fred T. (Frederick Thomas), 1865-1916","Russo-Japanese War, 1904-1905 -- Naval operations; Japan. Kaigun",VA,Browsing: History - General; Browsing: History - Warfare
# 74636,Text,2024-10-25,A daughter of strife,en,"Findlater, Jane Helen, 1866-1946",London (England) -- History -- 18th century -- Fiction,PR,Browsing: Gender & Sexuality Studies; Browsing: Fiction
# 74886,Text,2024-12-13,Rena's experiment,en,"Holmes, Mary Jane, 1825-1907; Grant, Gordon, 1875-1962 [Illustrator]",Domestic fiction; New England -- Fiction; Impostors and imposture -- Fiction; Man-woman relationships -- Fiction; Wills -- Fiction,PS,Browsing: History - American; Browsing: Fiction; Category: Romance; Category: Novels; Category: American Literature
# 74902,Text,2024-12-14,Madeline,en,"Holmes, Mary Jane, 1825-1907",Young women -- Fiction; Love stories; New England -- Fiction; Governesses -- Fiction,PS,Browsing: Teaching & Education; Browsing: Fiction; Category: Novels; Category: American Literature
# 74921,Text,2024-12-17,Lucy Harding,en,"Holmes, Mary Jane, 1825-1907; Grunwald, Charles, 1867-1910 [Illustrator]",Man-woman relationships -- Fiction; Women travelers -- Fiction; Americans -- Russia -- Fiction; Middle age -- Fiction,PS,Browsing: Russian Interest; Browsing: Fiction; Category: Historical Novels; Category: Romance; Category: Adventure; Category: Novels
# 74929,Text,2024-12-18,The Merivale banks,en,"Holmes, Mary Jane, 1825-1907; Grant, Gordon, 1875-1962 [Illustrator]",New England -- Fiction; Man-woman relationships -- Fiction; Singers -- Fiction; Banks and banking -- Fiction,PS,Browsing: Culture/Civilization/Society; Browsing: Fiction; Category: Novels; Category: American Literature
# 74973,Text,2024-12-25,Lives of the early Medici,en,"Ross, Janet, 1842-1927 [Editor]","Florence (Italy) -- History; Medici, House of; Medici, Lorenzo de', 1449-1492; Medici, Cosimo de', 1389-1464; Medici, Piero de', 1416-1469",DG,Browsing: Biographies; Browsing: History - European; Category: Biographies; Category: History - European; Category: History - Early Modern (c. 1450-1750)
# 75247,Text,2025-01-29,The coming of peace (A family catastrophe),en,"Hauptmann, Gerhart, 1862-1946; Achurch, Janet [Translator]; Wheeler, C. E. [Translator]",Christmas plays; German drama -- Translations into English,PT,Browsing: Literature; Browsing: Fiction; Category: Plays/Films/Dramas; Category: German Literature
# 75309,Text,2025-02-07,Paul Ralston,en,"Holmes, Mary Jane, 1825-1907",American fiction -- 19th century,PS,Browsing: Literature; Browsing: Fiction; Category: Novels; Category: American Literature
# 75538,Text,2025-03-06,Bog-land studies,en,"Barlow, Jane, 1856-1917",Stories in rhyme; Ireland -- Poetry; English poetry -- Irish authors,PR,Browsing: Culture/Civilization/Society; Browsing: Fiction; Category: Novels
# 75587,Text,2025-03-11,A creel of Irish stories,en,"Barlow, Jane, 1856-1917","Ireland -- Social life and customs -- Fiction; Short stories, English -- Irish authors",PR,"Browsing: Culture/Civilization/Society; Browsing: Fiction; Category: Short Stories; Category: Mythology, Legends & Folklore"
# 75616,Text,2025-03-15,"The British battle fleet, Vol. 1 (of 2)",en,"Jane, Fred T. (Frederick Thomas), 1865-1916; Wyllie, W. L. (William Lionel), 1851-1931 [Illustrator]","Great Britain -- History, Naval; Great Britain. Royal Navy -- History; Warships -- Great Britain -- History",DA,Browsing: History - British; Browsing: History - Warfare; Category: History - British; Category: History - Medieval/Middle Ages; Category: History - Early Modern (c. 1450-1750); Category: History - Modern (1750+); Category: History - Warfare
# 75617,Text,2025-03-15,"The British battle fleet, Vol. 2 (of 2)",en,"Jane, Fred T. (Frederick Thomas), 1865-1916; Wyllie, W. L. (William Lionel), 1851-1931 [Illustrator]","Great Britain -- History, Naval; Great Britain. Royal Navy -- History; Warships -- Great Britain -- History",DA,Browsing: History - British; Browsing: History - Warfare; Category: History - British; Category: History - Warfare; Category: Engineering & Technology
# 75709,Text,2025-03-25,Tales of the peerage and the peasantry,en,"Sullivan, Arabella Jane, 1797?-1839; Dacre, Barbarina, Lady, 1767-1854 [Editor]","Nithsdale, Winifred Maxwell, Countess of, 1672-1749 -- Fiction",PR,Browsing: History - British; Browsing: Fiction; Category: Short Stories; Category: Historical Novels; Category: Romance; Category: British Literature
# 75755,Text,2025-03-30,"Janet, a twin",en,"Whitehill, Dorothy; Gooch, Thelma, 1895-1973 [Illustrator]",Twins -- Juvenile fiction; Sisters -- Juvenile fiction; Reunions -- Juvenile fiction,PZ,Browsing: Children & Young Adult Reading; Browsing: Fiction; Category: Children & Young Adult Reading; Category: Novels; Category: American Literature
# 75808,Text,2025-04-07,Four square Jane,en,"Wallace, Edgar, 1875-1932; Tennant, C. Dudley (Charles Dudley), 1866-1952 [Illustrator]",Detective and mystery stories; England -- Fiction; Criminals -- Fiction,PR,"Browsing: Crime/Mystery; Browsing: Fiction; Category: Crime, Thrillers and Mystery; Category: Novels; Category: British Literature"
# 75823,Text,2025-04-08,By beach and bog-land,en,"Barlow, Jane, 1856-1917; Henry, Paul, 1876-1958 [Illustrator]","Ireland -- Fiction; Peasants -- Ireland -- Fiction; Short stories, English -- Irish authors",PR,Browsing: Culture/Civilization/Society; Browsing: Fiction; Category: Short Stories
# 75982,Text,2025-04-28,Recollections of a chaperon,en,"Sullivan, Arabella Jane, 1797?-1839; Dacre, Barbarina, Lady, 1767-1854 [Editor]",English fiction -- 19th century,PR,Browsing: Fiction; Category: Romance; Category: Novels; Category: British Literature
# 75986,Text,2025-04-29,Reminiscences of a student's life,en,"Harrison, Jane Ellen, 1850-1928","Autobiographies; Harrison, Jane Ellen, 1850-1928; Classicists -- Great Britain -- History -- 20th century -- Biography; Historians -- Great Britain -- 20th century -- Biography",CT,Browsing: Biographies; Browsing: History - Schools & Universities; Category: Biographies; Category: British Literature
# 76031,Text,2025-05-06,Beyond the pleasure principle,en,"Freud, Sigmund, 1856-1939; Hubback, C. J. M. (Caroline Jane Mary), 1871-1959 [Translator]",Psychoanalysis; Pleasure principle (Psychology),BF,Browsing: Philosophy & Ethics; Browsing: Psychiatry/Psychology; Category: Psychiatry/Psychology; Category: Philosophy & Ethics
# 76391,Text,2025-06-26,Fairy dreams,en,"Austin, Jane G. (Jane Goodwin), 1831-1894; Billings, Hammatt, 1818-1874 [Illustrator]","Children's stories, American; Fairies -- Juvenile fiction; Magic -- Juvenile fiction; Courts and courtiers -- Juvenile fiction",PZ,
# 76408,Text,2025-06-28,Willy's travels on the railroad,en,"Marcet, Mrs. (Jane Haldimand), 1769-1858",Children's stories; Nature stories; Country life -- Juvenile fiction; Railroad stories; Families -- Juvenile fiction,PZ,

# %%
import pandas as pd
import os
import requests

BASE_URL = "https://mirrorservice.org/sites/ftp.ibiblio.org/pub/docs/books/gutenberg"
OUTPUT_DIR = "books"

def get_possible_txt_urls(book_id):
    """Return list of possible URLs and corresponding filenames"""
    id_str = str(book_id)
    subpath = "/".join(id_str[:-1]) + f"/{id_str}" if len(id_str) > 1 else f"{id_str}"
    base_path = f"{BASE_URL}/{subpath}/{id_str}"

    return [
        (f"{base_path}.txt", f"{book_id}.txt"),
        (f"{base_path}-0.txt", f"{book_id}-0.txt"),
    ]

def download_and_save(url, dest_path):
    try:
        r = requests.get(url, stream=True, timeout=15)
        if r.ok:
            with open(dest_path, "wb") as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)
            return True
    except Exception as e:
        print(f"  ⚠️ Error downloading {url}: {e}")
    return False

def process_catalog(input_path="catalog_with_ids.csv", output_path="catalog_with_ids_and_files.csv",verbose=True):
    df = pd.read_csv(input_path)

    for i, row in df.iterrows():
        book_id = row["id"]
        if pd.isna(book_id):
            print(f"⚠️ Missing book ID at row {i}, skipping...")
            continue

        try:
            book_id = int(book_id)
        except:
            print(f"⚠️ Non Project Gutenburg book ID '{book_id}' at row {i}, skipping...")
            continue

        book_dir = os.path.join(OUTPUT_DIR, str(book_id))
        os.makedirs(book_dir, exist_ok=True)

        # Skip if already downloaded
        existing_files = os.listdir(book_dir)
        if existing_files:
            if verbose: print(f"✅ Already downloaded: {book_id}")
            dest_file_path = os.path.join(book_dir, existing_files[0])
            df.at[i, "file"] = dest_file_path
            continue


        if verbose: print(f"⬇️  Downloading book ID {book_id}...")

        for url, filename in get_possible_txt_urls(book_id):
            dest_file_path = os.path.join(book_dir, filename)
            if download_and_save(url, dest_file_path):
                print(f"   ✔️  Saved as {filename}")
                df.at[i, "file"] = dest_file_path
                break
        else:
            print(f"   ❌ Failed to download book ID {book_id}")

    df.to_csv(output_path, index=False)
    print(f"\n📄 Updated catalog saved to '{output_path}'")

process_catalog(verbose=False)
# Out:
# ⚠️ Non Project Gutenburg book ID 'ng35' at row 34, skipping...
#
# 📄 Updated catalog saved to 'catalog_with_ids_and_files.csv'

# %%
# !head catalog_with_ids_and_files.csv
# Out:
# id,title,author,year,description,file,tags,source,language
# 42671,Pride and Prejudice,Jane Austen,1813,A witty novel of manners and marriage among the British gentry.,books/42671/42671-0.txt,"literary-fiction/classic,romance",Project Gutenberg,English
# 15,"Moby-Dick; or, The Whale",Herman Melville,1851,An epic adventure of obsession and revenge on the high seas.,books/15/15-0.txt,"literary-fiction/classic,adventure,sea",Project Gutenberg,English
# 1661,The Adventures of Sherlock Holmes,Arthur Conan Doyle,1892,Twelve Sherlock Holmes stories that defined modern detective fiction.,books/1661/1661-0.txt,"mystery/classic,short-stories",Project Gutenberg,English
# 42324,"Frankenstein; or, The Modern Prometheus",Mary Shelley,1818,"The pioneering Gothic tale of science, ambition, and creation turned monster.",books/42324/42324-0.txt,"science-fiction/classic,gothic",Project Gutenberg,English
# 45839,Dracula,Bram Stoker,1897,The classic vampire novel that shaped modern horror.,books/45839/45839-0.txt,"horror/classic,gothic",Project Gutenberg,English
# 26740,The Picture of Dorian Gray,Oscar Wilde,1890,"A decadent portrait of youth, beauty, and moral corruption.",books/26740/26740.txt,"philosophy/aesthetics,gothic,literary-fiction/classic",Project Gutenberg,English
# 1184,The Count of Monte Cristo,Alexandre Dumas,1846,"A sweeping tale of betrayal, justice, and revenge set in post‑Napoleonic France.",books/1184/1184-0.txt,"adventure,classical-literature/French,revenge",Project Gutenberg,French
# 2600,War and Peace,Leo Tolstoy,1869,Tolstoy's vast panorama of Russian society during the Napoleonic Wars.,books/2600/2600-0.txt,"historical-fiction/classic,epic",Project Gutenberg,Russian
# 2554,Crime and Punishment,Fyodor Dostoevsky,1866,A psychological study of guilt and redemption following a brutal murder.,books/2554/2554-0.txt,"psychological-fiction,classical-literature/Russian",Project Gutenberg,Russian

# %%
# !head -n 100 books/42671/42671-0.txt
# Out:
# *** START OF THE PROJECT GUTENBERG EBOOK 42671 ***
#
# Note: Project Gutenberg also has an HTML version of this
#       file which includes the original illustrations.
#       See 42671-h.htm or 42671-h.zip:
#       (http://www.gutenberg.org/files/42671/42671-h/42671-h.htm)
#       or
#       (http://www.gutenberg.org/files/42671/42671-h.zip)
#
#
#       Images of the original pages are available through
#       Internet Archive. See
#       http://archive.org/stream/novelstextbasedo02austuoft#page/n23/mode/2up
#
#
# Transcriber's note:
#
#       Text enclosed by underscores is in italics (_italics_).
#
#       A carat character is used to denote superscription. Multiple
#       superscripted characters are enclosed by curly brackets
#       (example: M^{rs}).
#
#
#
#
#
# PRIDE AND PREJUDICE:
#
# A Novel.
#
# In Three Volumes.
#
# By the Author of "Sense and Sensibility."
#
# VOL. I.
#
#
#
#
#
#
#
# London:
# Printed for T. Egerton,
# Military Library, Whitehall.
# 1813.
#
#
#
#
# [Illustration: Morning Dress.
#
# _Invented by M^{rs} Bell 26 Charlotte Street Bedford Square._
#
# _Engraved for No. 72 of La Belle Assemblee 1^{st} July 1815_]
#
#
#
#
# PRIDE & PREJUDICE.
#
#
#
#
# CHAPTER I.
#
#
# It is a truth universally acknowledged, that a single man in possession
# of a good fortune, must be in want of a wife.
#
# However little known the feelings or views of such a man may be on his
# first entering a neighbourhood, this truth is so well fixed in the minds
# of the surrounding families, that he is considered as the rightful
# property of some one or other of their daughters.
#
# "My dear Mr. Bennet," said his lady to him one day, "have you heard that
# Netherfield Park is let at last?"
#
# Mr. Bennet replied that he had not.
#
# "But it is," returned she; "for Mrs. Long has just been here, and she
# told me all about it."
#
# Mr. Bennet made no answer.
#
# "Do not you want to know who has taken it?" cried his wife impatiently.
#
# "_You_ want to tell me, and I have no objection to hearing it."
#
# This was invitation enough.
#
# "Why, my dear, you must know, Mrs. Long says that Netherfield is taken
# by a young man of large fortune from the north of England; that he came
# down on Monday in a chaise and four to see the place, and was so much
# delighted with it that he agreed with Mr. Morris immediately; that he is
# to take possession before Michaelmas, and some of his servants are to be
# in the house by the end of next week."
#
# "What is his name?"

# %%
pd.read_csv('catalog_with_ids_and_files.csv').to_json('catalog.json', orient='records')

# %%
# !mkdir library
# !mv books library/
# !mv catalog.json library/
# !rm -f library.zip
# !zip -9r library.zip library/
# Out:
# mkdir: cannot create directory ‘library’: File exists
# mv: cannot stat 'books': No such file or directory
#   adding: library/ (stored 0%)
#   adding: library/books/ (stored 0%)
#   adding: library/books/7872/ (stored 0%)
#   adding: library/books/7869/ (stored 0%)
#   adding: library/books/1661/ (stored 0%)
#   adding: library/books/1661/1661-0.txt (deflated 63%)
#   adding: library/books/2383/ (stored 0%)
#   adding: library/books/2383/2383-0.txt (deflated 62%)
#   adding: library/books/20270/ (stored 0%)
#   adding: library/books/49487/ (stored 0%)
#   adding: library/books/49487/49487-0.txt (deflated 64%)
#   adding: library/books/26289/ (stored 0%)
#   adding: library/books/15492/ (stored 0%)
#   adding: library/books/15492/15492.txt (deflated 65%)
#   adding: library/books/9288/ (stored 0%)
#   adding: library/books/22382/ (stored 0%)
#   adding: library/books/22382/22382-0.txt (deflated 62%)
#   adding: library/books/35/ (stored 0%)
#   adding: library/books/35/35-0.txt (deflated 62%)
#   adding: library/books/21839/ (stored 0%)
#   adding: library/books/21839/21839-0.txt (deflated 64%)
#   adding: library/books/15/ (stored 0%)
#   adding: library/books/15/15-0.txt (deflated 59%)
#   adding: library/books/7094/ (stored 0%)
#   adding: library/books/42324/ (stored 0%)
#   adding: library/books/42324/42324-0.txt (deflated 62%)
#   adding: library/books/768/ (stored 0%)
#   adding: library/books/768/768-0.txt (deflated 61%)
#   adding: library/books/3160/ (stored 0%)
#   adding: library/books/3160/3160-0.txt (deflated 61%)
#   adding: library/books/17405/ (stored 0%)
#   adding: library/books/17405/17405-0.txt (deflated 63%)
#   adding: library/books/63203/ (stored 0%)
#   adding: library/books/63203/63203-0.txt (deflated 61%)
#   adding: library/books/8608/ (stored 0%)
#   adding: library/books/19640/ (stored 0%)
#   adding: library/books/19640/19640.txt (deflated 65%)
#   adding: library/books/1497/ (stored 0%)
#   adding: library/books/1497/1497-0.txt (deflated 65%)
#   adding: library/books/1998/ (stored 0%)
#   adding: library/books/1998/1998-0.txt (deflated 63%)
#   adding: library/books/2641/ (stored 0%)
#   adding: library/books/2641/2641-0.txt (deflated 62%)
#   adding: library/books/2814/ (stored 0%)
#   adding: library/books/2814/2814-0.txt (deflated 63%)
#   adding: library/books/17401/ (stored 0%)
#   adding: library/books/8800/ (stored 0%)
#   adding: library/books/8800/8800-0.txt (deflated 60%)
#   adding: library/books/42671/ (stored 0%)
#   adding: library/books/42671/42671-0.txt (deflated 64%)
#   adding: library/books/20000/ (stored 0%)
#   adding: library/books/76/ (stored 0%)
#   adding: library/books/76/76-0.txt (deflated 63%)
#   adding: library/books/28797/ (stored 0%)
#   adding: library/books/26/ (stored 0%)
#   adding: library/books/26/26-0.txt (deflated 59%)
#   adding: library/books/526/ (stored 0%)
#   adding: library/books/526/526.txt (deflated 60%)
#   adding: library/books/1400/ (stored 0%)
#   adding: library/books/1400/1400-0.txt (deflated 63%)
#   adding: library/books/1184/ (stored 0%)
#   adding: library/books/1184/1184-0.txt (deflated 64%)
#   adding: library/books/4300/ (stored 0%)
#   adding: library/books/4300/4300-0.txt (deflated 58%)
#   adding: library/books/26226/ (stored 0%)
#   adding: library/books/205/ (stored 0%)
#   adding: library/books/205/205-0.txt (deflated 60%)
#   adding: library/books/135/ (stored 0%)
#   adding: library/books/135/135-0.txt (deflated 62%)
#   adding: library/books/28947/ (stored 0%)
#   adding: library/books/23722/ (stored 0%)
#   adding: library/books/22964/ (stored 0%)
#   adding: library/books/23979/ (stored 0%)
#   adding: library/books/215/ (stored 0%)
#   adding: library/books/215/215-0.txt (deflated 61%)
#   adding: library/books/1322/ (stored 0%)
#   adding: library/books/1322/1322-0.txt (deflated 62%)
#   adding: library/books/2600/ (stored 0%)
#   adding: library/books/2600/2600-0.txt (deflated 64%)
#   adding: library/books/35997/ (stored 0%)
#   adding: library/books/35997/35997-0.txt (deflated 63%)
#   adding: library/books/103/ (stored 0%)
#   adding: library/books/103/103-0.txt (deflated 63%)
#   adding: library/books/20594/ (stored 0%)
#   adding: library/books/43936/ (stored 0%)
#   adding: library/books/43936/43936.txt (deflated 66%)
#   adding: library/books/45839/ (stored 0%)
#   adding: library/books/45839/45839-0.txt (deflated 62%)
#   adding: library/books/23077/ (stored 0%)
#   adding: library/books/844/ (stored 0%)
#   adding: library/books/844/844-0.txt (deflated 65%)
#   adding: library/books/65473/ (stored 0%)
#   adding: library/books/65473/65473-0.txt (deflated 63%)
#   adding: library/books/541/ (stored 0%)
#   adding: library/books/541/541.txt (deflated 61%)
#   adding: library/books/203/ (stored 0%)
#   adding: library/books/203/203-0.txt (deflated 61%)
#   adding: library/books/19678/ (stored 0%)
#   adding: library/books/19678/19678.txt (deflated 65%)
#   adding: library/books/36/ (stored 0%)
#   adding: library/books/36/36-0.txt (deflated 62%)
#   adding: library/books/51713/ (stored 0%)
#   adding: library/books/51713/51713-0.txt (deflated 57%)
#   adding: library/books/28733/ (stored 0%)
#   adding: library/books/26291/ (stored 0%)
#   adding: library/books/26740/ (stored 0%)
#   adding: library/books/26740/26740.txt (deflated 62%)
#   adding: library/books/940/ (stored 0%)
#   adding: library/books/940/940-0.txt (deflated 63%)
#   adding: library/books/1260/ (stored 0%)
#   adding: library/books/1260/1260-0.txt (deflated 60%)
#   adding: library/books/26298/ (stored 0%)
#   adding: library/books/2554/ (stored 0%)
#   adding: library/books/2554/2554-0.txt (deflated 63%)
#   adding: library/books/28054/ (stored 0%)
#   adding: library/books/28054/28054-0.txt (deflated 64%)
#   adding: library/books/996/ (stored 0%)
#   adding: library/books/996/996-0.txt (deflated 63%)
#   adding: library/books/8958/ (stored 0%)
#   adding: library/books/164/ (stored 0%)
#   adding: library/books/164/164-0.txt (deflated 62%)
#   adding: library/books/98/ (stored 0%)
#   adding: library/books/98/98-0.txt (deflated 63%)
#   adding: library/books/4517/ (stored 0%)
#   adding: library/books/4517/4517-0.txt (deflated 62%)
#   adding: library/catalog.csv (deflated 60%)
#   adding: library/catalog.json (deflated 71%)
